# %% [markdown]
# # Ambiente de desarrollo
#
# Agenda para hoy:
#
# - Revisando jupyter notebook en más detalle
# - Trabajando con módulos en jupyter
# - jupyter notebooks con jupyterlab, google colab y VSCODE
# - "The missing semester": https://missing.csail.mit.edu/
#     - Shell/Terminal: ZSH: Autocompleteación, Búsqueda, Temas y Plugins
#     - Editores: vim (https://www.openvim.com/)
#     - Control de versiones

# %% [markdown]
# ## Módulos externos
#
# - Ayuda y autocompletación
# - Demostración de magia `autoreload`
#
# Esta magia nos permite editar el módulo "en vivo" sin tener que reiniciar el cuadernillo

# %%
from script_interesante import saludar

# %%
saludar?

# %%
saludar("Pablo")
saludar("Andrés")

# %% [markdown]
# ## Notebooks en Jupyterlab, Google Colab y VSCode
#
# - Jupyterlab: Interfaz más flexible, más similar a una IDE completa
# - Google colab: Servicio de Google para trabajar en cuadernillos jupyter de forma colaborativa y en la nube
# - VSCode: IDE completa con excelete integración con cuadernillos jupyter

# %%
# Ejemplo: Figura interactiva

# %% [markdown]
# ### Jupyter lab
#
# - Crear un ambiente de conda e instalar `jupyterlab` y `ipympl`, este último para tener gráficos interactivos
# - Comparación entre jupyter notebook y jupyterlab: https://www.analyticsvidhya.com/blog/2020/06/10-powerful-reasons-jupyterlab-data-science/

# %% [markdown]
# ### Google colab
#
# Ejemplo: https://colab.research.google.com/drive/1-RfsaAUnQ6foX6yGHGbbp_e_P5zR1dVv#scrollTo=VFD6qjd_6npb

# %% [markdown]
# ### VSCode
#
# - Instalar las extensiones para Python y Jupyter
# - F1: Select interpreter and default shell
# - Tutorial de VSCode y Python: https://code.visualstudio.com/docs/python/python-tutorial

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('FSdIoJdSnig')
