# %%
from IPython.display import SVG

# %%
# %%file img/intro.diag
# blockdiag {
#     #orientation = portrait
#     default_fontsize = 12;
#     A [label="Jupyter"]
#     B [label="IPython"]
#     C [label="NumPy/pandas/Scipy"]
#     D [label="BLAS/LAPACK/MKL"]
#     A -> B
#     B -> C
#     C -> D [style = "dashed"]
#
# }
# Out:
# Overwriting img/intro.diag

# %%
!~/.local/bin/blockdiag -Tsvg img/intro.diag

# %%
SVG("img/intro.svg")

# %%
# %%file img/groupby.diag
# blockdiag {
#     #orientation = portrait
#     default_fontsize = 14;
#     A [label="SPLIT"]
#     B [label="APPLY"]
#     C [label="COMBINE"]
#     A -> B
#     B -> C
#     group {
#           color = "#CCCCCC";
#           fontsize = 20;
#
#           A -> B;
#           B -> C;
#       }
#
# }
# Out:
# Overwriting img/groupby.diag

# %%
!~/.local/bin/blockdiag -Tsvg img/groupby.diag

# %%
SVG("img/groupby.svg")
